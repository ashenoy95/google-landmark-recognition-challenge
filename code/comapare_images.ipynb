# %%
import numpy as np
from tqdm import tqdm
import tensorflow as tf
from PIL import Image
import os

# %%
test = tf.convert_to_tensor(x[0], np.int32)

# %%
resized = tf.cast(tf.image.resize_images(test, [299, 299]), tf.uint8)

# %%
init = tf.global_variables_initializer()
sess = tf.Session()
sess.run(init)

# %%
resized_np = sess.run(resized)

# %%
Image.fromarray(x[0], 'RGB')
# Out:
# <PIL.Image.Image image mode=RGB size=227x227 at 0x7F03F8CC6F98>

# %%
Image.fromarray(resized_np, 'RGB')
# Out:
# <PIL.Image.Image image mode=RGB size=299x299 at 0x7F03F012C9E8>

# %%
img = Image.open('/share/jproject/fg538/r-006-gpu-4/data/train/10026/395e5ec5d608b4c1.jpg')

# %%
for file in os.listdir('/share/jproject/fg538/r-006-gpu-4/data/train/10026/'):
    print(file)
    break
# Out:
# 395e5ec5d608b4c1.jpg

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1200x1600 at 0x7F03E80FEB00>

# %%
img_227_pil = Image.open('/share/jproject/fg538/r-006-gpu-4/data/train_resized/10026/395e5ec5d608b4c1.jpg')

# %%
img_227_pil
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=227x227 at 0x7F03E81726A0>

# %%
Image.fromarray(sess.run(tf.cast(tf.image.resize_images(np.array(img_227_pil), [299, 299]), tf.uint8)), 'RGB')
# Out:
# <PIL.Image.Image image mode=RGB size=299x299 at 0x7F03E8799C50>

# %%
img.resize((299, 299))
# Out:
# <PIL.Image.Image image mode=RGB size=299x299 at 0x7F03C815CF98>
